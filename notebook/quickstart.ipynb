# %%
import requests

# %% [markdown]
# # 0. Install requests
#
# You can find the official doc [here](https://docs.python-requests.org/en/latest/user/install/#install)
#
# ```bash
# # -m means run pip module as a script, to avoid the pip.py
# python -m pip install requests
# ```
#
# # 1. Make a request
#
# Now, let’s try to get a webpage. For this example, let’s get GitHub’s public timeline:

# %%
response = requests.get("https://api.github.com/events")

# %% [markdown]
# All the information that server sends back to us are in the response. In below example, we print the response code 200, which means success. We will show details of response in section 2

# %%
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# # 1.1 Other http request
#
# Off course, requests can do other possible http request type, below are some code example:
#
# ```python
# requests.post('https://httpbin.org/post', data={'key':'value'})
# requests.put('https://httpbin.org/put', data={'key':'value'})
# requests.delete('https://httpbin.org/delete')
# requests.head('https://httpbin.org/get')
# requests.patch('https://httpbin.org/patch', data={'key':'value'})
# requests.options('https://httpbin.org/get')
# ```
# Note for put, post, patch, the data parameter allows you to pass request payload.
#
# # 1.2 Params for get
#
# When you make a quest for http, you can also pass parameter in the URL. below is an example

# %%
get_params = {'key1': 'value1', 'key2': 'value2'}
r1 = requests.get('https://httpbin.org/get', params=get_params)

# %%
# you can check the url of your request by using .url
print(r1.url)
# Out:
# https://httpbin.org/get?key1=value1&key2=value2

# %% [markdown]
# # 2 Response content
#
# We know how to make a request now, Now let's check the response of the request

# %%
print(response.text)
# Out:
# [{"id":"20893240420","type":"PullRequestReviewEvent","actor":{"id":29139814,"login":"GCsabi","display_login":"GCsabi","gravatar_id":"","url":"https://api.github.com/users/GCsabi","avatar_url":"https://avatars.githubusercontent.com/u/29139814?"},"repo":{"id":466697561,"name":"joladnijo/joladnijo-webapp","url":"https://api.github.com/repos/joladnijo/joladnijo-webapp"},"payload":{"action":"created","review":{"id":918715493,"node_id":"PRR_kwDOG9E9Wc42wnxl","user":{"login":"GCsabi","id":29139814,"node_id":"MDQ6VXNlcjI5MTM5ODE0","avatar_url":"https://avatars.githubusercontent.com/u/29139814?v=4","gravatar_id":"","url":"https://api.github.com/users/GCsabi","html_url":"https://github.com/GCsabi","followers_url":"https://api.github.com/users/GCsabi/followers","following_url":"https://api.github.com/users/GCsabi/following{/other_user}","gists_url":"https://api.github.com/users/GCsabi/gists{/gist_id}","starred_url":"https://api.github.com/users/GCsabi/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/GCsabi/subscriptions","organizations_url":"https://api.github.com/users/GCsabi/orgs","repos_url":"https://api.github.com/users/GCsabi/repos","events_url":"https://api.github.com/users/GCsabi/events{/privacy}","received_events_url":"https://api.github.com/users/GCsabi/received_events","type":"User","site_admin":false},"body":null,"commit_id":"dbffdf1865ebe7c14d091952028ba513cedccc61","submitted_at":"2022-03-23T12:50:56Z","state":"commented","html_url":"https://github.com/joladnijo/joladnijo-webapp/pull/27#pullrequestreview-918715493","pull_request_url":"https://api.github.com/repos/joladnijo/joladnijo-webapp/pulls/27","author_association":"NONE","_links":{"html":{"href":"https://github.com/joladnijo/joladnijo-webapp/pull/27#pullrequestreview-918715493"},"pull_request":{"href":"https://api.github.com/repos/joladnijo/joladnijo-webapp/pulls/27"}}},"pull_request":{"url":"https://api.github.com/repos/joladnijo/joladnijo-webapp/pulls/27","id":887125843,"node_id":"PR_kwDOG9E9Wc404HdT","html_url":"https://github.com/joladnijo/joladnijo-webapp/pull/27","diff_url":"https://github.com/joladnijo/joladnijo-webapp/pull/27.diff","patch_url":"https://github.com/joladnijo/joladnijo-webapp/pull/27.patch","issue_url":"https://api.github.com/repos/joladnijo/joladnijo-webapp/issues/27","number":27,"state":"open","locked":false,"title":"Tesztframework integralas","user":{"login":"GCsabi","id":29139814,"node_id":"MDQ6VXNlcjI5MTM5ODE0","avatar_url":"https://avatars.githubusercontent.com/u/29139814?v=4","gravatar_id":"","url":"https://api.github.com/users/GCsabi","html_url":"https://github.com/GCsabi","followers_url":"https://api.github.com/users/GCsabi/followers","following_url":"https://api.github.com/users/GCsabi/following{/other_user}","gists_url":"https://api.github.com/users/GCsabi/gists{/gist_id}","starred_url":"https://api.github.com/users/GCsabi/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/GCsabi/subscriptions","organizations_url":"https://api.github.com/users/GCsabi/orgs","repos_url":"https://api.github.com/users/GCsabi/repos","events_url":"https://api.github.com/users/GCsabi/events{/privacy}","received_events_url":"https://api.github.com/users/GCsabi/received_events","type":"User","site_admin":false},"body":"lokálisan elindítottam, backend nélkül ugyan, de nem tűnt problémásnak","created_at":"2022-03-23T11:57:12Z","updated_at":"2022-03-23T12:50:56Z","closed_at":null,"merged_at":null,"merge_commit_sha":"aa53d4ed17002883337154cc44add0adcf87dd7d","assignee":{"login":"molnarbence","id":8344072,"node_id":"MDQ6VXNlcjgzNDQwNzI=","avatar_url":"https://avatars.githubusercontent.com/u/8344072?v=4","gravatar_id":"","url":"https://api.github.com/users/molnarbence","html_url":"https://github.com/molnarbence","followers_url":"https://api.github.com/users/molnarbence/followers","following_url":"https://api.github.com/users/molnarbence/following{/other_user}","gists_url":"https://api.github.com/users/molnarbence/gists{/ ...

# %% [markdown]
# You can notice the github server send back the event timeline.
#
# Note: Requests will automatically decode content from the server. Most unicode charsets are seamlessly decoded.
#
# When you make a request, Requests makes educated guesses about the encoding of the response based on the HTTP headers. The **text encoding guessed by Requests is used when you access r.text**. You can find out what encoding Requests is using, and change it, using the **.encoding** property.
#
# The encoding guessed by Requests is utf-8, we can change it by assigning a new value

# %% [markdown]
# ## 2.1 Encoding

# %%
response.encoding
# Out:
# 'utf-8'

# %%
# When you change it, it will be used when you call .text
response.encoding = 'latin-8'
response.text
# Out:
# '[{"id":"20893240420","type":"PullRequestReviewEvent","actor":{"id":29139814,"login":"GCsabi","display_login":"GCsabi","gravatar_id":"","url":"https://api.github.com/users/GCsabi","avatar_url":"https://avatars.githubusercontent.com/u/29139814?"},"repo":{"id":466697561,"name":"joladnijo/joladnijo-webapp","url":"https://api.github.com/repos/joladnijo/joladnijo-webapp"},"payload":{"action":"created","review":{"id":918715493,"node_id":"PRR_kwDOG9E9Wc42wnxl","user":{"login":"GCsabi","id":29139814,"node_id":"MDQ6VXNlcjI5MTM5ODE0","avatar_url":"https://avatars.githubusercontent.com/u/29139814?v=4","gravatar_id":"","url":"https://api.github.com/users/GCsabi","html_url":"https://github.com/GCsabi","followers_url":"https://api.github.com/users/GCsabi/followers","following_url":"https://api.github.com/users/GCsabi/following{/other_user}","gists_url":"https://api.github.com/users/GCsabi/gists{/gist_id}","starred_url":"https://api.github.com/users/GCsabi/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/GCsabi/subscriptions","organizations_url":"https://api.github.com/users/GCsabi/orgs","repos_url":"https://api.github.com/users/GCsabi/repos","events_url":"https://api.github.com/users/GCsabi/events{/privacy}","received_events_url":"https://api.github.com/users/GCsabi/received_events","type":"User","site_admin":false},"body":null,"commit_id":"dbffdf1865ebe7c14d091952028ba513cedccc61","submitted_at":"2022-03-23T12:50:56Z","state":"commented","html_url":"https://github.com/joladnijo/joladnijo-webapp/pull/27#pullrequestreview-918715493","pull_request_url":"https://api.github.com/repos/joladnijo/joladnijo-webapp/pulls/27","author_association":"NONE","_links":{"html":{"href":"https://github.com/joladnijo/joladnijo-webapp/pull/27#pullrequestreview-918715493"},"pull_request":{"href":"https://api.github.com/repos/joladnijo/joladnijo-webapp/pulls/27"}}},"pull_request":{"url":"https://api.github.com/repos/joladnijo/joladnijo-webapp/pulls/27","id":887125843,"node_id":"PR_kwDOG9E9Wc404HdT","html_url":"https://github.com/joladnijo/joladnijo-webapp/pull/27","diff_url":"https://github.com/joladnijo/joladnijo-webapp/pull/27.diff","patch_url":"https://github.com/joladnijo/joladnijo-webapp/pull/27.patch","issue_url":"https://api.github.com/repos/joladnijo/joladnijo-webapp/issues/27","number":27,"state":"open","locked":false,"title":"Tesztframework integralas","user":{"login":"GCsabi","id":29139814,"node_id":"MDQ6VXNlcjI5MTM5ODE0","avatar_url":"https://avatars.githubusercontent.com/u/29139814?v=4","gravatar_id":"","url":"https://api.github.com/users/GCsabi","html_url":"https://github.com/GCsabi","followers_url":"https://api.github.com/users/GCsabi/followers","following_url":"https://api.github.com/users/GCsabi/following{/other_user}","gists_url":"https://api.github.com/users/GCsabi/gists{/gist_id}","starred_url":"https://api.github.com/users/GCsabi/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/GCsabi/subscriptions","organizations_url":"https://api.github.com/users/GCsabi/orgs","repos_url":"https://api.github.com/users/GCsabi/repos","events_url":"https://api.github.com/users/GCsabi/events{/privacy}","received_events_url":"https://api.github.com/users/GCsabi/received_events","type":"User","site_admin":false},"body":"lokálisan elindítottam, backend nélkül ugyan, de nem tűnt problémásnak","created_at":"2022-03-23T11:57:12Z","updated_at":"2022-03-23T12:50:56Z","closed_at":null,"merged_at":null,"merge_commit_sha":"aa53d4ed17002883337154cc44add0adcf87dd7d","assignee":{"login":"molnarbence","id":8344072,"node_id":"MDQ6VXNlcjgzNDQwNzI=","avatar_url":"https://avatars.githubusercontent.com/u/8344072?v=4","gravatar_id":"","url":"https://api.github.com/users/molnarbence","html_url":"https://github.com/molnarbence","followers_url":"https://api.github.com/users/molnarbence/followers","following_url":"https://api.github.com/users/molnarbence/following{/other_user}","gists_url":"https://api.github.com/users/molnarbence/gists{ ...

# %% [markdown]
# This feature is useful when you have specific knowledge of the encoding. For example, HTML and XML have the ability to specify their encoding in their body. In situations like this, you should use **r.content to find the encoding, and then set r.encoding**. This will let you use r.text with the correct encoding.

# %% [markdown]
# ## 2.2 Binary Response Content
#
# As the **.text** get you the text version of the response, the **.content** get you the binary version of the response. For example, if you request an image or photo, the response is more likely in byte.
#
# You can use other python module to open properly the byte response. Below example shows how to open an image byte response.
#
# ```python
# from PIL import Image
# from io import BytesIO
#
# i = Image.open(BytesIO(r.content))
# ```

# %% [markdown]
# ## 2.3 Json Response Content
#
# There’s also a builtin JSON decoder, in case you’re dealing with JSON data:

# %%
r = requests.get('https://api.github.com/events')
r.json()
# Out:
# [{'id': '20895085563',
#   'type': 'CreateEvent',
#   'actor': {'id': 32468651,
#    'login': 'EtienneLt',
#    'display_login': 'EtienneLt',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/EtienneLt',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32468651?'},
#   'repo': {'id': 105284146,
#    'name': 'powsybl/powsybl-core',
#    'url': 'https://api.github.com/repos/powsybl/powsybl-core'},
#   'payload': {'ref': 'set-loadflow-parameters-with-a-map',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'A framework to build power system oriented software',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-03-23T14:16:58Z',
#   'org': {'id': 29916668,
#    'login': 'powsybl',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/powsybl',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29916668?'}},
#  {'id': '20895085519',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 12514844,
#    'login': 'robertkiel',
#    'display_login': 'robertkiel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/robertkiel',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12514844?'},
#   'repo': {'id': 286462146,
#    'name': 'hoprnet/hoprnet',
#    'url': 'https://api.github.com/repos/hoprnet/hoprnet'},
#   'payload': {'action': 'closed',
#    'number': 3680,
#    'pull_request': {'url': 'https://api.github.com/repos/hoprnet/hoprnet/pulls/3680',
#     'id': 887270702,
#     'node_id': 'PR_kwDOERMQws404q0u',
#     'html_url': 'https://github.com/hoprnet/hoprnet/pull/3680',
#     'diff_url': 'https://github.com/hoprnet/hoprnet/pull/3680.diff',
#     'patch_url': 'https://github.com/hoprnet/hoprnet/pull/3680.patch',
#     'issue_url': 'https://api.github.com/repos/hoprnet/hoprnet/issues/3680',
#     'number': 3680,
#     'state': 'closed',
#     'locked': False,
#     'title': 'bump libp2p-noise',
#     'user': {'login': 'robertkiel',
#      'id': 12514844,
#      'node_id': 'MDQ6VXNlcjEyNTE0ODQ0',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/12514844?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/robertkiel',
#      'html_url': 'https://github.com/robertkiel',
#      'followers_url': 'https://api.github.com/users/robertkiel/followers',
#      'following_url': 'https://api.github.com/users/robertkiel/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/robertkiel/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/robertkiel/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/robertkiel/subscriptions',
#      'organizations_url': 'https://api.github.com/users/robertkiel/orgs',
#      'repos_url': 'https://api.github.com/users/robertkiel/repos',
#      'events_url': 'https://api.github.com/users/robertkiel/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/robertkiel/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Bump libp2p-noise to include this bugfix https://github.com/ChainSafe/js-libp2p-noise/pull/130',
#     'created_at': '2022-03-23T14:14:49Z',
#     'updated_at': '2022-03-23T14:16:57Z',
#     'closed_at': '2022-03-23T14:16:57Z',
#     'merged_at': '2022-03-23T14:16:56Z',
#     'merge_commit_sha': '17c5b8d89be3918ae8b67a724812ecddb0d7c7c2',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/hoprnet/hoprnet/pulls/3680/commits',
#     'review_comments_url': 'https://api.github.com/repos/hoprnet/hoprnet/pulls/3680/comments',
#     'review_comment_url': 'https://api.github.com/repos/hoprnet/hoprnet/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/hoprnet/hoprnet/issues/3680/comments',
#     'statuses_url': 'https://api.github.com/repos/hoprnet/hoprnet/statuses/9df46dcf84daf7550ebf9caddc37f6a6503de021',
#     'head': {'label': 'hoprnet:hotfix/bump-libp2p-noise',
#      'ref': 'hotfix/bump-libp2p-noise',
#      'sha': '9df46dcf84daf7550ebf9caddc37f6a6503de021',
#      'user': {'login': 'hoprnet',
#       'id': 55133542,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU1MTMzNTQy',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/55133542?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/hoprnet',
#       'html_url': 'https://github.com/hoprnet',
#       'followers_url': 'https://api.github.com/users/hoprnet/followers',
#       'following_url': 'https://api.github.com/users/hoprnet/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/hoprnet/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/hoprnet/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/hoprnet/subscriptions',
#       'organizations_url': 'https://api.github.com/users/hoprnet/orgs',
#       'repos_url': 'https://api.github.com/users/hoprnet/repos',
#       'events_url': 'https://api.github.com/users/hoprnet/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/hoprnet/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 286462146,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyODY0NjIxNDY=',
#       'name': 'hoprnet',
#       'full_name': 'hoprnet/hoprnet',
#       'private': False,
#       'owner': {'login': 'hoprnet',
#        'id': 55133542,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU1MTMzNTQy',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/55133542?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/hoprnet',
#        'html_url': 'https://github.com/hoprnet',
#        'followers_url': 'https://api.github.com/users/hoprnet/followers',
#        'following_url': 'https://api.github.com/users/hoprnet/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/hoprnet/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/hoprnet/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/hoprnet/subscriptions',
#        'organizations_url': 'https://api.github.com/users/hoprnet/orgs',
#        'repos_url': 'https://api.github.com/users/hoprnet/repos',
#        'events_url': 'https://api.github.com/users/hoprnet/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/hoprnet/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/hoprnet/hoprnet',
#       'description': 'HOPR is an open incentivized mixnet which enables privacy-preserving point-to-point data exchange. HOPR is similar to Tor but actually private, decentralized and economically sustainable.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/hoprnet/hoprnet',
#       'forks_url': 'https://api.github.com/repos/hoprnet/hoprnet/forks',
#       'keys_url': 'https://api.github.com/repos/hoprnet/hoprnet/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/hoprnet/hoprnet/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/hoprnet/hoprnet/teams',
#       'hooks_url': 'https://api.github.com/repos/hoprnet/hoprnet/hooks',
#       'issue_events_url': 'https://api.github.com/repos/hoprnet/hoprnet/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/hoprnet/hoprnet/events',
#       'assignees_url': 'https://api.github.com/repos/hoprnet/hoprnet/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/hoprnet/hoprnet/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/hoprnet/hoprnet/tags',
#       'blobs_url': 'https://api.github.com/repos/hoprnet/hoprnet/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/hoprnet/hoprnet/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/hoprnet/hoprnet/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/hoprnet/hoprnet/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/hoprnet/hoprnet/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/hoprnet/hoprnet/languages',
#       'stargazers_url': 'https://api.github.com/repos/hoprnet/hoprnet/stargazers',
#       'contributors_url': 'https://api.github.com/repos/hoprnet/hoprnet/contributors',
#       'subscribers_url': 'https://api.github.com/repos/hoprnet/hoprnet/subscribers',
#       'subscription_url': 'https://api.github.com/repos/hoprnet/hoprnet/subscription',
#       'commits_url': 'https://api.github.com/repos/hoprnet/hoprnet/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/hoprnet/hoprnet/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/hoprnet/hoprnet/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/hoprnet/hoprnet/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/hoprnet/hoprnet/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/hoprnet/hoprnet/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/hoprnet/hoprnet/merges',
#       'archive_url': 'https://api.github.com/repos/hoprnet/hoprnet/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/hoprnet/hoprnet/downloads',
#       'issues_url': 'https://api.github.com/repos/hoprnet/hoprnet/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/hoprnet/hoprnet/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/hoprnet/hoprnet/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/hoprnet/hoprnet/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/hoprnet/hoprnet/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/hoprnet/hoprnet/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/hoprnet/hoprnet/deployments',
#       'created_at': '2020-08-10T11:57:55Z',
#       'updated_at': '2022-03-18T08:06:00Z',
#       'pushed_at': '2022-03-23T14:16:56Z',
#       'git_url': 'git://github.com/hoprnet/hoprnet.git',
#       'ssh_url': 'git@github.com:hoprnet/hoprnet.git',
#       'clone_url': 'https://github.com/hoprnet/hoprnet.git',
#       'svn_url': 'https://github.com/hoprnet/hoprnet',
#       'homepage': 'https://hoprnet.org',
#       'size': 188664,
#       'stargazers_count': 109,
#       'watchers_count': 109,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 44,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 237,
#       'license': {'key': 'gpl-3.0',
#        'name': 'GNU General Public License v3.0',
#        'spdx_id': 'GPL-3.0',
#        'url': 'https://api.github.com/licenses/gpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTk='},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': ['blockchain', 'ethereum', 'privacy'],
#       'visibility': 'public',
#       'forks': 44,
#       'open_issues': 237,
#       'watchers': 109,
#       'default_branch': 'master'}},
#     'base': {'label': 'hoprnet:release/ouagadougou',
#      'ref': 'release/ouagadougou',
#      'sha': '6776eae4afb9ee4e888104b071b72c0f7b26b1c8',
#      'user': {'login': 'hoprnet',
#       'id': 55133542,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU1MTMzNTQy',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/55133542?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/hoprnet',
#       'html_url': 'https://github.com/hoprnet',
#       'followers_url': 'https://api.github.com/users/hoprnet/followers',
#       'following_url': 'https://api.github.com/users/hoprnet/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/hoprnet/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/hoprnet/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/hoprnet/subscriptions',
#       'organizations_url': 'https://api.github.com/users/hoprnet/orgs',
#       'repos_url': 'https://api.github.com/users/hoprnet/repos',
#       'events_url': 'https://api.github.com/users/hoprnet/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/hoprnet/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 286462146,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyODY0NjIxNDY=',
#       'name': 'hoprnet',
#       'full_name': 'hoprnet/hoprnet',
#       'private': False,
#       'owner': {'login': 'hoprnet',
#        'id': 55133542,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU1MTMzNTQy',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/55133542?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/hoprnet',
#        'html_url': 'https://github.com/hoprnet',
#        'followers_url': 'https://api.github.com/users/hoprnet/followers',
#        'following_url': 'https://api.github.com/users/hoprnet/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/hoprnet/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/hoprnet/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/hoprnet/subscriptions',
#        'organizations_url': 'https://api.github.com/users/hoprnet/orgs',
#        'repos_url': 'https://api.github.com/users/hoprnet/repos',
#        'events_url': 'https://api.github.com/users/hoprnet/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/hoprnet/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/hoprnet/hoprnet',
#       'description': 'HOPR is an open incentivized mixnet which enables privacy-preserving point-to-point data exchange. HOPR is similar to Tor but actually private, decentralized and economically sustainable.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/hoprnet/hoprnet',
#       'forks_url': 'https://api.github.com/repos/hoprnet/hoprnet/forks',
#       'keys_url': 'https://api.github.com/repos/hoprnet/hoprnet/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/hoprnet/hoprnet/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/hoprnet/hoprnet/teams',
#       'hooks_url': 'https://api.github.com/repos/hoprnet/hoprnet/hooks',
#       'issue_events_url': 'https://api.github.com/repos/hoprnet/hoprnet/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/hoprnet/hoprnet/events',
#       'assignees_url': 'https://api.github.com/repos/hoprnet/hoprnet/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/hoprnet/hoprnet/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/hoprnet/hoprnet/tags',
#       'blobs_url': 'https://api.github.com/repos/hoprnet/hoprnet/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/hoprnet/hoprnet/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/hoprnet/hoprnet/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/hoprnet/hoprnet/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/hoprnet/hoprnet/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/hoprnet/hoprnet/languages',
#       'stargazers_url': 'https://api.github.com/repos/hoprnet/hoprnet/stargazers',
#       'contributors_url': 'https://api.github.com/repos/hoprnet/hoprnet/contributors',
#       'subscribers_url': 'https://api.github.com/repos/hoprnet/hoprnet/subscribers',
#       'subscription_url': 'https://api.github.com/repos/hoprnet/hoprnet/subscription',
#       'commits_url': 'https://api.github.com/repos/hoprnet/hoprnet/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/hoprnet/hoprnet/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/hoprnet/hoprnet/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/hoprnet/hoprnet/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/hoprnet/hoprnet/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/hoprnet/hoprnet/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/hoprnet/hoprnet/merges',
#       'archive_url': 'https://api.github.com/repos/hoprnet/hoprnet/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/hoprnet/hoprnet/downloads',
#       'issues_url': 'https://api.github.com/repos/hoprnet/hoprnet/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/hoprnet/hoprnet/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/hoprnet/hoprnet/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/hoprnet/hoprnet/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/hoprnet/hoprnet/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/hoprnet/hoprnet/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/hoprnet/hoprnet/deployments',
#       'created_at': '2020-08-10T11:57:55Z',
#       'updated_at': '2022-03-18T08:06:00Z',
#       'pushed_at': '2022-03-23T14:16:56Z',
#       'git_url': 'git://github.com/hoprnet/hoprnet.git',
#       'ssh_url': 'git@github.com:hoprnet/hoprnet.git',
#       'clone_url': 'https://github.com/hoprnet/hoprnet.git',
#       'svn_url': 'https://github.com/hoprnet/hoprnet',
#       'homepage': 'https://hoprnet.org',
#       'size': 188664,
#       'stargazers_count': 109,
#       'watchers_count': 109,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 44,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 237,
#       'license': {'key': 'gpl-3.0',
#        'name': 'GNU General Public License v3.0',
#        'spdx_id': 'GPL-3.0',
#        'url': 'https://api.github.com/licenses/gpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTk='},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': ['blockchain', 'ethereum', 'privacy'],
#       'visibility': 'public',
#       'forks': 44,
#       'open_issues': 237,
#       'watchers': 109,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/hoprnet/hoprnet/pulls/3680'},
#      'html': {'href': 'https://github.com/hoprnet/hoprnet/pull/3680'},
#      'issue': {'href': 'https://api.github.com/repos/hoprnet/hoprnet/issues/3680'},
#      'comments': {'href': 'https://api.github.com/repos/hoprnet/hoprnet/issues/3680/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/hoprnet/hoprnet/pulls/3680/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/hoprnet/hoprnet/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/hoprnet/hoprnet/pulls/3680/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/hoprnet/hoprnet/statuses/9df46dcf84daf7550ebf9caddc37f6a6503de021'}},
#     'author_association': 'MEMBER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'robertkiel',
#      'id': 12514844,
#      'node_id': 'MDQ6VXNlcjEyNTE0ODQ0',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/12514844?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/robertkiel',
#      'html_url': 'https://github.com/robertkiel',
#      'followers_url': 'https://api.github.com/users/robertkiel/followers',
#      'following_url': 'https://api.github.com/users/robertkiel/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/robertkiel/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/robertkiel/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/robertkiel/subscriptions',
#      'organizations_url': 'https://api.github.com/users/robertkiel/orgs',
#      'repos_url': 'https://api.github.com/users/robertkiel/repos',
#      'events_url': 'https://api.github.com/users/robertkiel/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/robertkiel/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 1,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 10,
#     'deletions': 10,
#     'changed_files': 4}},
#   'public': True,
#   'created_at': '2022-03-23T14:16:57Z',
#   'org': {'id': 55133542,
#    'login': 'hoprnet',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/hoprnet',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55133542?'}},
#  {'id': '20895087270',
#   'type': 'PushEvent',
#   'actor': {'id': 75618134,
#    'login': 'hieroglyphica',
#    'display_login': 'hieroglyphica',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hieroglyphica',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/75618134?'},
#   'repo': {'id': 447579927,
#    'name': 'hieroglyphica/vision',
#    'url': 'https://api.github.com/repos/hieroglyphica/vision'},
#   'payload': {'push_id': 9427287380,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c1de31fdc7be0894db5ad36c2342ad4526a9e280',
#    'before': 'a400ad3d6ec4471bc7e3762de07bdd127b5f2518',
#    'commits': [{'sha': 'c1de31fdc7be0894db5ad36c2342ad4526a9e280',
#      'author': {'email': 'temporalequation@gmail.com',
#       'name': 'hieroglyphica'},
#      'message': 'filter comment',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hieroglyphica/vision/commits/c1de31fdc7be0894db5ad36c2342ad4526a9e280'}]},
#   'public': True,
#   'created_at': '2022-03-23T14:17:02Z'},
#  {'id': '20895085485',
#   'type': 'CreateEvent',
#   'actor': {'id': 20373878,
#    'login': 'Alaxend0l',
#    'display_login': 'Alaxend0l',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Alaxend0l',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20373878?'},
#   'repo': {'id': 473218338,
#    'name': 'JakopinA/JakopinA.github.io',
#    'url': 'https://api.github.com/repos/JakopinA/JakopinA.github.io'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-03-23T14:16:57Z'},
#  {'id': '20895085272',
#   'type': 'PushEvent',
#   'actor': {'id': 101473453,
#    'login': 'juyjuy3',
#    'display_login': 'juyjuy3',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/juyjuy3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101473453?'},
#   'repo': {'id': 469158152,
#    'name': 'juyjuy3/file',
#    'url': 'https://api.github.com/repos/juyjuy3/file'},
#   'payload': {'push_id': 9427286451,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '729f3fe20e7a35eca5891c88b075f73d49b3b365',
#    'before': '9e131d6fe1c52e1e0b9ddbfaea3d46ea920c55a0',
#    'commits': [{'sha': '729f3fe20e7a35eca5891c88b075f73d49b3b365',
#      'author': {'email': '101473453+juyjuy3@users.noreply.github.com',
#       'name': 'juyjuy3'},
#      'message': 'add',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/juyjuy3/file/commits/729f3fe20e7a35eca5891c88b075f73d49b3b365'}]},
#   'public': True,
#   'created_at': '2022-03-23T14:16:57Z'},
#  {'id': '20895085484',
#   'type': 'WatchEvent',
#   'actor': {'id': 86996763,
#    'login': 'yaoyaoJin',
#    'display_login': 'yaoyaoJin',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yaoyaoJin',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/86996763?'},
#   'repo': {'id': 210571563,
#    'name': 'Snailclimb/spring-security-jwt-guide',
#    'url': 'https://api.github.com/repos/Snailclimb/spring-security-jwt-guide'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2022-03-23T14:16:57Z'},
#  {'id': '20895087295',
#   'type': 'PullRequestReviewEvent',
#   'actor': {'id': 1378201,
#    'login': 'dmytroyarmak',
#    'display_login': 'dmytroyarmak',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dmytroyarmak',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1378201?'},
#   'repo': {'id': 213370612,
#    'name': 'kontist/js-sdk',
#    'url': 'https://api.github.com/repos/kontist/js-sdk'},
#   'payload': {'action': 'created',
#    'review': {'id': 918855824,
#     'node_id': 'PRR_kwDODLfG9M42xKCQ',
#     'user': {'login': 'dmytroyarmak',
#      'id': 1378201,
#      'node_id': 'MDQ6VXNlcjEzNzgyMDE=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/1378201?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dmytroyarmak',
#      'html_url': 'https://github.com/dmytroyarmak',
#      'followers_url': 'https://api.github.com/users/dmytroyarmak/followers',
#      'following_url': 'https://api.github.com/users/dmytroyarmak/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dmytroyarmak/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dmytroyarmak/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dmytroyarmak/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dmytroyarmak/orgs',
#      'repos_url': 'https://api.github.com/users/dmytroyarmak/repos',
#      'events_url': 'https://api.github.com/users/dmytroyarmak/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dmytroyarmak/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'commit_id': 'd04ffac316a29b278100a926514449e47cc942f9',
#     'submitted_at': '2022-03-23T14:17:02Z',
#     'state': 'approved',
#     'html_url': 'https://github.com/kontist/js-sdk/pull/271#pullrequestreview-918855824',
#     'pull_request_url': 'https://api.github.com/repos/kontist/js-sdk/pulls/271',
#     'author_association': 'CONTRIBUTOR',
#     '_links': {'html': {'href': 'https://github.com/kontist/js-sdk/pull/271#pullrequestreview-918855824'},
#      'pull_request': {'href': 'https://api.github.com/repos/kontist/js-sdk/pulls/271'}}},
#    'pull_request': {'url': 'https://api.github.com/repos/kontist/js-sdk/pulls/271',
#     'id': 887234122,
#     'node_id': 'PR_kwDODLfG9M404h5K',
#     'html_url': 'https://github.com/kontist/js-sdk/pull/271',
#     'diff_url': 'https://github.com/kontist/js-sdk/pull/271.diff',
#     'patch_url': 'https://github.com/kontist/js-sdk/pull/271.patch',
#     'issue_url': 'https://api.github.com/repos/kontist/js-sdk/issues/271',
#     'number': 271,
#     'state': 'open',
#     'locked': False,
#     'title': 'Release-0.40.0',
#     'user': {'login': 'sinahashemy',
#      'id': 27877253,
#      'node_id': 'MDQ6VXNlcjI3ODc3MjUz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/27877253?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/sinahashemy',
#      'html_url': 'https://github.com/sinahashemy',
#      'followers_url': 'https://api.github.com/users/sinahashemy/followers',
#      'following_url': 'https://api.github.com/users/sinahashemy/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/sinahashemy/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/sinahashemy/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/sinahashemy/subscriptions',
#      'organizations_url': 'https://api.github.com/users/sinahashemy/orgs',
#      'repos_url': 'https://api.github.com/users/sinahashemy/repos',
#      'events_url': 'https://api.github.com/users/sinahashemy/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/sinahashemy/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Release-0.40.0',
#     'created_at': '2022-03-23T13:42:28Z',
#     'updated_at': '2022-03-23T14:17:02Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': 'd6c653d1b97d8f903943c2b337f71b06bd597bd3',
#     'assignee': {'login': 'sinahashemy',
#      'id': 27877253,
#      'node_id': 'MDQ6VXNlcjI3ODc3MjUz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/27877253?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/sinahashemy',
#      'html_url': 'https://github.com/sinahashemy',
#      'followers_url': 'https://api.github.com/users/sinahashemy/followers',
#      'following_url': 'https://api.github.com/users/sinahashemy/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/sinahashemy/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/sinahashemy/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/sinahashemy/subscriptions',
#      'organizations_url': 'https://api.github.com/users/sinahashemy/orgs',
#      'repos_url': 'https://api.github.com/users/sinahashemy/repos',
#      'events_url': 'https://api.github.com/users/sinahashemy/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/sinahashemy/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'sinahashemy',
#       'id': 27877253,
#       'node_id': 'MDQ6VXNlcjI3ODc3MjUz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/27877253?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/sinahashemy',
#       'html_url': 'https://github.com/sinahashemy',
#       'followers_url': 'https://api.github.com/users/sinahashemy/followers',
#       'following_url': 'https://api.github.com/users/sinahashemy/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/sinahashemy/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/sinahashemy/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/sinahashemy/subscriptions',
#       'organizations_url': 'https://api.github.com/users/sinahashemy/orgs',
#       'repos_url': 'https://api.github.com/users/sinahashemy/repos',
#       'events_url': 'https://api.github.com/users/sinahashemy/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/sinahashemy/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_reviewers': [{'login': 'sonicdoe',
#       'id': 652793,
#       'node_id': 'MDQ6VXNlcjY1Mjc5Mw==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/652793?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/sonicdoe',
#       'html_url': 'https://github.com/sonicdoe',
#       'followers_url': 'https://api.github.com/users/sonicdoe/followers',
#       'following_url': 'https://api.github.com/users/sonicdoe/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/sonicdoe/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/sonicdoe/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/sonicdoe/subscriptions',
#       'organizations_url': 'https://api.github.com/users/sonicdoe/orgs',
#       'repos_url': 'https://api.github.com/users/sonicdoe/repos',
#       'events_url': 'https://api.github.com/users/sonicdoe/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/sonicdoe/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/kontist/js-sdk/pulls/271/commits',
#     'review_comments_url': 'https://api.github.com/repos/kontist/js-sdk/pulls/271/comments',
#     'review_comment_url': 'https://api.github.com/repos/kontist/js-sdk/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/kontist/js-sdk/issues/271/comments',
#     'statuses_url': 'https://api.github.com/repos/kontist/js-sdk/statuses/d04ffac316a29b278100a926514449e47cc942f9',
#     'head': {'label': 'kontist:release-candidate',
#      'ref': 'release-candidate',
#      'sha': 'd04ffac316a29b278100a926514449e47cc942f9',
#      'user': {'login': 'kontist',
#       'id': 16915961,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE2OTE1OTYx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/16915961?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/kontist',
#       'html_url': 'https://github.com/kontist',
#       'followers_url': 'https://api.github.com/users/kontist/followers',
#       'following_url': 'https://api.github.com/users/kontist/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/kontist/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/kontist/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/kontist/subscriptions',
#       'organizations_url': 'https://api.github.com/users/kontist/orgs',
#       'repos_url': 'https://api.github.com/users/kontist/repos',
#       'events_url': 'https://api.github.com/users/kontist/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/kontist/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 213370612,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMTMzNzA2MTI=',
#       'name': 'js-sdk',
#       'full_name': 'kontist/js-sdk',
#       'private': False,
#       'owner': {'login': 'kontist',
#        'id': 16915961,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE2OTE1OTYx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/16915961?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/kontist',
#        'html_url': 'https://github.com/kontist',
#        'followers_url': 'https://api.github.com/users/kontist/followers',
#        'following_url': 'https://api.github.com/users/kontist/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/kontist/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/kontist/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/kontist/subscriptions',
#        'organizations_url': 'https://api.github.com/users/kontist/orgs',
#        'repos_url': 'https://api.github.com/users/kontist/repos',
#        'events_url': 'https://api.github.com/users/kontist/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/kontist/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/kontist/js-sdk',
#       'description': 'JavaScript SDK for connecting to Kontist',
#       'fork': False,
#       'url': 'https://api.github.com/repos/kontist/js-sdk',
#       'forks_url': 'https://api.github.com/repos/kontist/js-sdk/forks',
#       'keys_url': 'https://api.github.com/repos/kontist/js-sdk/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/kontist/js-sdk/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/kontist/js-sdk/teams',
#       'hooks_url': 'https://api.github.com/repos/kontist/js-sdk/hooks',
#       'issue_events_url': 'https://api.github.com/repos/kontist/js-sdk/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/kontist/js-sdk/events',
#       'assignees_url': 'https://api.github.com/repos/kontist/js-sdk/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/kontist/js-sdk/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/kontist/js-sdk/tags',
#       'blobs_url': 'https://api.github.com/repos/kontist/js-sdk/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/kontist/js-sdk/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/kontist/js-sdk/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/kontist/js-sdk/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/kontist/js-sdk/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/kontist/js-sdk/languages',
#       'stargazers_url': 'https://api.github.com/repos/kontist/js-sdk/stargazers',
#       'contributors_url': 'https://api.github.com/repos/kontist/js-sdk/contributors',
#       'subscribers_url': 'https://api.github.com/repos/kontist/js-sdk/subscribers',
#       'subscription_url': 'https://api.github.com/repos/kontist/js-sdk/subscription',
#       'commits_url': 'https://api.github.com/repos/kontist/js-sdk/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/kontist/js-sdk/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/kontist/js-sdk/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/kontist/js-sdk/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/kontist/js-sdk/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/kontist/js-sdk/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/kontist/js-sdk/merges',
#       'archive_url': 'https://api.github.com/repos/kontist/js-sdk/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/kontist/js-sdk/downloads',
#       'issues_url': 'https://api.github.com/repos/kontist/js-sdk/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/kontist/js-sdk/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/kontist/js-sdk/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/kontist/js-sdk/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/kontist/js-sdk/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/kontist/js-sdk/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/kontist/js-sdk/deployments',
#       'created_at': '2019-10-07T11:54:39Z',
#       'updated_at': '2021-12-21T10:00:12Z',
#       'pushed_at': '2022-03-23T13:42:28Z',
#       'git_url': 'git://github.com/kontist/js-sdk.git',
#       'ssh_url': 'git@github.com:kontist/js-sdk.git',
#       'clone_url': 'https://github.com/kontist/js-sdk.git',
#       'svn_url': 'https://github.com/kontist/js-sdk',
#       'homepage': None,
#       'size': 7976,
#       'stargazers_count': 13,
#       'watchers_count': 13,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': ['api',
#        'banking',
#        'graphql',
#        'javascript',
#        'javascript-sdk',
#        'kontist',
#        'oauth2',
#        'sdk',
#        'typescript'],
#       'visibility': 'public',
#       'forks': 1,
#       'open_issues': 2,
#       'watchers': 13,
#       'default_branch': 'master'}},
#     'base': {'label': 'kontist:master',
#      'ref': 'master',
#      'sha': '87452cf81195386c461af073b8f14fda9d8b87c6',
#      'user': {'login': 'kontist',
#       'id': 16915961,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE2OTE1OTYx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/16915961?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/kontist',
#       'html_url': 'https://github.com/kontist',
#       'followers_url': 'https://api.github.com/users/kontist/followers',
#       'following_url': 'https://api.github.com/users/kontist/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/kontist/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/kontist/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/kontist/subscriptions',
#       'organizations_url': 'https://api.github.com/users/kontist/orgs',
#       'repos_url': 'https://api.github.com/users/kontist/repos',
#       'events_url': 'https://api.github.com/users/kontist/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/kontist/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 213370612,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMTMzNzA2MTI=',
#       'name': 'js-sdk',
#       'full_name': 'kontist/js-sdk',
#       'private': False,
#       'owner': {'login': 'kontist',
#        'id': 16915961,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE2OTE1OTYx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/16915961?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/kontist',
#        'html_url': 'https://github.com/kontist',
#        'followers_url': 'https://api.github.com/users/kontist/followers',
#        'following_url': 'https://api.github.com/users/kontist/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/kontist/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/kontist/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/kontist/subscriptions',
#        'organizations_url': 'https://api.github.com/users/kontist/orgs',
#        'repos_url': 'https://api.github.com/users/kontist/repos',
#        'events_url': 'https://api.github.com/users/kontist/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/kontist/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/kontist/js-sdk',
#       'description': 'JavaScript SDK for connecting to Kontist',
#       'fork': False,
#       'url': 'https://api.github.com/repos/kontist/js-sdk',
#       'forks_url': 'https://api.github.com/repos/kontist/js-sdk/forks',
#       'keys_url': 'https://api.github.com/repos/kontist/js-sdk/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/kontist/js-sdk/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/kontist/js-sdk/teams',
#       'hooks_url': 'https://api.github.com/repos/kontist/js-sdk/hooks',
#       'issue_events_url': 'https://api.github.com/repos/kontist/js-sdk/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/kontist/js-sdk/events',
#       'assignees_url': 'https://api.github.com/repos/kontist/js-sdk/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/kontist/js-sdk/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/kontist/js-sdk/tags',
#       'blobs_url': 'https://api.github.com/repos/kontist/js-sdk/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/kontist/js-sdk/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/kontist/js-sdk/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/kontist/js-sdk/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/kontist/js-sdk/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/kontist/js-sdk/languages',
#       'stargazers_url': 'https://api.github.com/repos/kontist/js-sdk/stargazers',
#       'contributors_url': 'https://api.github.com/repos/kontist/js-sdk/contributors',
#       'subscribers_url': 'https://api.github.com/repos/kontist/js-sdk/subscribers',
#       'subscription_url': 'https://api.github.com/repos/kontist/js-sdk/subscription',
#       'commits_url': 'https://api.github.com/repos/kontist/js-sdk/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/kontist/js-sdk/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/kontist/js-sdk/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/kontist/js-sdk/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/kontist/js-sdk/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/kontist/js-sdk/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/kontist/js-sdk/merges',
#       'archive_url': 'https://api.github.com/repos/kontist/js-sdk/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/kontist/js-sdk/downloads',
#       'issues_url': 'https://api.github.com/repos/kontist/js-sdk/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/kontist/js-sdk/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/kontist/js-sdk/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/kontist/js-sdk/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/kontist/js-sdk/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/kontist/js-sdk/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/kontist/js-sdk/deployments',
#       'created_at': '2019-10-07T11:54:39Z',
#       'updated_at': '2021-12-21T10:00:12Z',
#       'pushed_at': '2022-03-23T13:42:28Z',
#       'git_url': 'git://github.com/kontist/js-sdk.git',
#       'ssh_url': 'git@github.com:kontist/js-sdk.git',
#       'clone_url': 'https://github.com/kontist/js-sdk.git',
#       'svn_url': 'https://github.com/kontist/js-sdk',
#       'homepage': None,
#       'size': 7976,
#       'stargazers_count': 13,
#       'watchers_count': 13,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': ['api',
#        'banking',
#        'graphql',
#        'javascript',
#        'javascript-sdk',
#        'kontist',
#        'oauth2',
#        'sdk',
#        'typescript'],
#       'visibility': 'public',
#       'forks': 1,
#       'open_issues': 2,
#       'watchers': 13,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/kontist/js-sdk/pulls/271'},
#      'html': {'href': 'https://github.com/kontist/js-sdk/pull/271'},
#      'issue': {'href': 'https://api.github.com/repos/kontist/js-sdk/issues/271'},
#      'comments': {'href': 'https://api.github.com/repos/kontist/js-sdk/issues/271/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/kontist/js-sdk/pulls/271/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/kontist/js-sdk/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/kontist/js-sdk/pulls/271/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/kontist/js-sdk/statuses/d04ffac316a29b278100a926514449e47cc942f9'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2022-03-23T14:17:02Z',
#   'org': {'id': 16915961,
#    'login': 'kontist',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/kontist',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16915961?'}},
#  {'id': '20895085388',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 70644875,
#    'login': 'ourainbows',
#    'display_login': 'ourainbows',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ourainbows',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/70644875?'},
#   'repo': {'id': 468097221,
#    'name': 'CristianMontoya98/Legacy-Red-social-Progr-mate',
#    'url': 'https://api.github.com/repos/CristianMontoya98/Legacy-Red-social-Progr-mate'},
#   'payload': {'action': 'opened',
#    'number': 17,
#    'pull_request': {'url': 'https://api.github.com/repos/CristianMontoya98/Legacy-Red-social-Progr-mate/pulls/17',
#     'id': 887273018,
#     'node_id': 'PR_kwDOG-aYxc404rY6',
#     'html_url': 'https://github.com/CristianMontoya98/Legacy-Red-social-Progr-mate/pull/17',
#     'diff_url': 'https://github.com/CristianMontoya98/Legacy-Red-social-Progr-mate/pull/17.diff',
#     'patch_url': 'https://github.com/CristianMontoya98/Legacy-Red-social-Progr-mate/pull/17.patch',
#     'issue_url': 'https://api.github.com/repos/CristianMontoya98/Legacy-Red-social-Progr-mate/issues/17',
#     'number': 17,
#     'state': 'open',
#     'locked': False,
#     'title': 'Changes on admin cohort',
#     'user': {'login': 'ourainbows',
#      'id': 70644875,
#      'node_id': 'MDQ6VXNlcjcwNjQ0ODc1',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/70644875?v=4',
#      'gravatar_id': '',
# ...
#       'full_name': 'kiegroup/droolsjbpm-build-bootstrap',
#       'private': False,
#       'owner': {'login': 'kiegroup',
#        'id': 517980,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjUxNzk4MA==',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/517980?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/kiegroup',
#        'html_url': 'https://github.com/kiegroup',
#        'followers_url': 'https://api.github.com/users/kiegroup/followers',
#        'following_url': 'https://api.github.com/users/kiegroup/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/kiegroup/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/kiegroup/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/kiegroup/subscriptions',
#        'organizations_url': 'https://api.github.com/users/kiegroup/orgs',
#        'repos_url': 'https://api.github.com/users/kiegroup/repos',
#        'events_url': 'https://api.github.com/users/kiegroup/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/kiegroup/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/kiegroup/droolsjbpm-build-bootstrap',
#       'description': 'The build bootstrap contains the parent pom, guidelines and scripts for Drools, jBPM and OptaPlanner.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap',
#       'forks_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/forks',
#       'keys_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/teams',
#       'hooks_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/hooks',
#       'issue_events_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/events',
#       'assignees_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/tags',
#       'blobs_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/languages',
#       'stargazers_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/stargazers',
#       'contributors_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/contributors',
#       'subscribers_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/subscribers',
#       'subscription_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/subscription',
#       'commits_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/merges',
#       'archive_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/downloads',
#       'issues_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/deployments',
#       'created_at': '2011-02-18T13:12:01Z',
#       'updated_at': '2022-03-03T07:16:37Z',
#       'pushed_at': '2022-03-23T14:11:33Z',
#       'git_url': 'git://github.com/kiegroup/droolsjbpm-build-bootstrap.git',
#       'ssh_url': 'git@github.com:kiegroup/droolsjbpm-build-bootstrap.git',
#       'clone_url': 'https://github.com/kiegroup/droolsjbpm-build-bootstrap.git',
#       'svn_url': 'https://github.com/kiegroup/droolsjbpm-build-bootstrap',
#       'homepage': 'http://www.kiegroup.org',
#       'size': 11198,
#       'stargazers_count': 201,
#       'watchers_count': 201,
#       'language': 'Shell',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': True,
#       'forks_count': 409,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 12,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': ['hacktoberfest'],
#       'visibility': 'public',
#       'forks': 409,
#       'open_issues': 12,
#       'watchers': 201,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/pulls/1917'},
#      'html': {'href': 'https://github.com/kiegroup/droolsjbpm-build-bootstrap/pull/1917'},
#      'issue': {'href': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/issues/1917'},
#      'comments': {'href': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/issues/1917/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/pulls/1917/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/pulls/1917/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/kiegroup/droolsjbpm-build-bootstrap/statuses/37ee6dae654f29a0df22e661dd58be2b3e2ccabf'}},
#     'author_association': 'MEMBER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': False,
#     'mergeable_state': 'unstable',
#     'merged_by': None,
#     'comments': 1,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 6,
#     'deletions': 0,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2022-03-23T14:17:02Z',
#   'org': {'id': 517980,
#    'login': 'kiegroup',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/kiegroup',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/517980?'}},
#  {'id': '20895085329',
#   'type': 'PushEvent',
#   'actor': {'id': 5343198,
#    'login': 'ysoftman',
#    'display_login': 'ysoftman',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ysoftman',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5343198?'},
#   'repo': {'id': 108200568,
#    'name': 'ysoftman/test_code',
#    'url': 'https://api.github.com/repos/ysoftman/test_code'},
#   'payload': {'push_id': 9427286485,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'b1b74f926a9ba182bdc5281b1c6b2e29043e0995',
#    'before': '2fda4f372297a85dbd8866bc4b5d32bf605b0c51',
#    'commits': [{'sha': 'b1b74f926a9ba182bdc5281b1c6b2e29043e0995',
#      'author': {'email': 'ysoftman@gmail.com', 'name': 'ysoftman'},
#      'message': 'update comment',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ysoftman/test_code/commits/b1b74f926a9ba182bdc5281b1c6b2e29043e0995'}]},
#   'public': True,
#   'created_at': '2022-03-23T14:16:57Z'},
#  {'id': '20895085256',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 471156435,
#    'name': '11ty/11ty-community',
#    'url': 'https://api.github.com/repos/11ty/11ty-community'},
#   'payload': {'push_id': 9427286450,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '833f7dd0b020245652a4973025baf8942e1c50ea',
#    'before': '4b27ff9772edc25eb08487f525eadcbf7e9278e2',
#    'commits': [{'sha': '833f7dd0b020245652a4973025baf8942e1c50ea',
#      'author': {'email': 'action@github.com', 'name': 'GitHub Action'},
#      'message': 'Adding data file for #42',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/11ty/11ty-community/commits/833f7dd0b020245652a4973025baf8942e1c50ea'}]},
#   'public': True,
#   'created_at': '2022-03-23T14:16:57Z',
#   'org': {'id': 35147177,
#    'login': '11ty',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/11ty',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35147177?'}},
#  {'id': '20895085319',
#   'type': 'PushEvent',
#   'actor': {'id': 9092682,
#    'login': 'TomBursch',
#    'display_login': 'TomBursch',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TomBursch',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9092682?'},
#   'repo': {'id': 335558846,
#    'name': 'TomBursch/kitchenowl-backend',
#    'url': 'https://api.github.com/repos/TomBursch/kitchenowl-backend'},
#   'payload': {'push_id': 9427286692,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'c53d42c0e510ab9d539b3232ef75c2ea285bb36c',
#    'before': '54bd8cce61de756d3d60ea872c07a1244850b6fb',
#    'commits': [{'sha': 'c53d42c0e510ab9d539b3232ef75c2ea285bb36c',
#      'author': {'email': 'tombursch@gmail.com', 'name': 'Tom Bursch'},
#      'message': 'Prepare release 22',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/TomBursch/kitchenowl-backend/commits/c53d42c0e510ab9d539b3232ef75c2ea285bb36c'}]},
#   'public': True,
#   'created_at': '2022-03-23T14:16:57Z'},
#  {'id': '20895085122',
#   'type': 'PushEvent',
#   'actor': {'id': 5789411,
#    'login': 'clairesunstudio',
#    'display_login': 'clairesunstudio',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/clairesunstudio',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5789411?'},
#   'repo': {'id': 66381106,
#    'name': 'massgov/mayflower-artifacts',
#    'url': 'https://api.github.com/repos/massgov/mayflower-artifacts'},
#   'payload': {'push_id': 9427286597,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/patternlab/DP-23805-add-page-banner-buttons',
#    'head': '98f8a6d63bf2ed483e9e8c23a7a8dc40c7d29c5d',
#    'before': '90d29413173af26223c18dfebe198a4018d502b0',
#    'commits': [{'sha': '98f8a6d63bf2ed483e9e8c23a7a8dc40c7d29c5d',
#      'author': {'email': 'ci.bot@mass.gov', 'name': 'MassGov Bot'},
#      'message': 'Automated commit based on 9ca80a8f7493859641af09f417c16a0aebcf43cc',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/massgov/mayflower-artifacts/commits/98f8a6d63bf2ed483e9e8c23a7a8dc40c7d29c5d'}]},
#   'public': True,
#   'created_at': '2022-03-23T14:16:56Z',
#   'org': {'id': 7770800,
#    'login': 'massgov',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/massgov',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7770800?'}},
#  {'id': '20895087112',
#   'type': 'PushEvent',
#   'actor': {'id': 2467509,
#    'login': 'wtondossantos',
#    'display_login': 'wtondossantos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wtondossantos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2467509?'},
#   'repo': {'id': 460808944,
#    'name': 'wtondossantos/JaVisitei.Brasil.Api',
#    'url': 'https://api.github.com/repos/wtondossantos/JaVisitei.Brasil.Api'},
#   'payload': {'push_id': 9427287280,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/release',
#    'head': '9b5aa238d8257846e17e6dccb8fac53d6198e209',
#    'before': 'fadc50d3b297f8b645a517024829089570463be0',
#    'commits': [{'sha': 'aceb9e3c43402813e346e1f4a4bb37aa87a54b19',
#      'author': {'email': 'wellington@wton.com.br', 'name': 'wtondossantos'},
#      'message': 'update',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/wtondossantos/JaVisitei.Brasil.Api/commits/aceb9e3c43402813e346e1f4a4bb37aa87a54b19'},
#     {'sha': '9b5aa238d8257846e17e6dccb8fac53d6198e209',
#      'author': {'email': 'wellington@wton.com.br',
#       'name': 'Wellington dos Santos Castor'},
#      'message': 'Merge pull request #181 from wtondossantos/develop\n\nupdate',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wtondossantos/JaVisitei.Brasil.Api/commits/9b5aa238d8257846e17e6dccb8fac53d6198e209'}]},
#   'public': True,
#   'created_at': '2022-03-23T14:17:02Z'},
#  {'id': '20895085271',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 340772535,
#    'name': 'William5553/william5553',
#    'url': 'https://api.github.com/repos/William5553/william5553'},
#   'payload': {'push_id': 9427286623,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'a69321bc312bee4031f1b4422b2fad04cc668ea4',
#    'before': '4fd953726b21ca7b3104827af008d088b13c0177',
#    'commits': [{'sha': 'a69321bc312bee4031f1b4422b2fad04cc668ea4',
#      'author': {'email': 'github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'chore: autopublish 2022-03-23T14:16:55Z',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/William5553/william5553/commits/a69321bc312bee4031f1b4422b2fad04cc668ea4'}]},
#   'public': True,
#   'created_at': '2022-03-23T14:16:57Z'},
#  {'id': '20895087118',
#   'type': 'PushEvent',
#   'actor': {'id': 58833107,
#    'login': 'kbsjgy349',
#    'display_login': 'kbsjgy349',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kbsjgy349',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58833107?'},
#   'repo': {'id': 227724995,
#    'name': 'kbsjgy349/djy',
#    'url': 'https://api.github.com/repos/kbsjgy349/djy'},
#   'payload': {'push_id': 9427287554,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '906a36118a2a5edff32fc6b476f37b5930278e9e',
#    'before': '5ca219726178d8f83c3c11471163df43b376708d',
#    'commits': [{'sha': '906a36118a2a5edff32fc6b476f37b5930278e9e',
#      'author': {'email': '58833107+kbsjgy349@users.noreply.github.com',
#       'name': 'kbsjgy349'},
#      'message': 'Update ncid187_2.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kbsjgy349/djy/commits/906a36118a2a5edff32fc6b476f37b5930278e9e'}]},
#   'public': True,
#   'created_at': '2022-03-23T14:17:02Z'}]

# %% [markdown]
# In case the JSON decoding fails, r.json() raises an exception. For example, if the response gets a 204 (No Content), or if the response contains invalid JSON, attempting r.json() raises requests.exceptions.JSONDecodeError. This wrapper exception provides interoperability for multiple exceptions that may be thrown by different python versions and json serialization libraries.
#
# It should be noted that the success of the call to r.json() does not indicate the success of the response. Some servers may return a JSON object in a failed response (e.g. error details with HTTP 500). Such JSON will be decoded and returned. To check that a request is successful, use r.raise_for_status() or check r.status_code is what you expect.

# %% [markdown]
# ## 2.4 Raw Response Content
#
# In the rare case that you’d like to get the raw socket response from the server, you can access r.raw. If you want to do this, make sure you set stream=True in your initial request. Once you do, you can do this:

# %%
r = requests.get('https://api.github.com/events', stream=True)
r.raw

# %%
r.raw.read(10)
# Out:
# b''

# %% [markdown]
# In general, however, you should write the streamed content to a file like below example:

# %%
filename = "/tmp/github_event.txt"
with open(filename, 'wb') as fd:
    for chunk in r.iter_content(chunk_size=128):
        fd.write(chunk)
# Out:
# ---------------------------------------------------------------------------
# StreamConsumedError                       Traceback (most recent call last)
# Input In [25], in <cell line: 2>()
#       1 filename="/tmp/github_event.txt"
#       2 with open(filename, 'wb') as fd:
# ----> 3     for chunk in r.iter_content(chunk_size=128):
#       4         fd.write(chunk)
#
# File ~/.cache/pypoetry/virtualenvs/pyhttpexample-8vE2bHV0-py3.8/lib/python3.8/site-packages/requests/models.py:779, in Response.iter_content(self, chunk_size, decode_unicode)
#     776     self._content_consumed = True
#     778 if self._content_consumed and isinstance(self._content, bool):
# --> 779     raise StreamConsumedError()
#     780 elif chunk_size is not None and not isinstance(chunk_size, int):
#     781     raise TypeError("chunk_size must be an int, it is instead a %s." % type(chunk_size))
#
# StreamConsumedError:

# %% [markdown]
# Using Response.iter_content will handle a lot of what you would otherwise have to handle when using Response.raw directly. When streaming a download, the above is the preferred and recommended way to retrieve the content. Note that chunk_size can be freely adjusted to a number that may better fit your use cases.

# %% [markdown]
# # 3. Request header
#
# To customize headers, you pass a dictionary of HTTP headers to get() using the **headers parameter**. For example, you can change your previous search request to highlight matching search terms in the results by specifying the text-match media type in the Accept header:

# %%
url_param = {'q': 'requests+language:python'}
my_header = {'Accept': 'application/vnd.github.v3.text-match+json'}

response = requests.get(
    'https://api.github.com/search/repositories',
    params=url_param,
    headers=my_header,
)

# View the new `text-matches` array which provides information
# about your search term within the results
json_response = response.json()
repository = json_response['items'][0]
print(f'Text matches: {repository["text_matches"]}')
# Out:
# Text matches: [{'object_url': 'https://api.github.com/repositories/4290214', 'object_type': 'Repository', 'property': 'description', 'fragment': 'Requests + Gevent = <3', 'matches': [{'text': 'Requests', 'indices': [0, 8]}]}]

# %% [markdown]
# The Accept header tells the server what content types your application can handle. In this case, since you’re expecting the matching search terms to be highlighted, you’re using the header value application/vnd.github.v3.text-match+json, which is a proprietary GitHub Accept header where the content is a special JSON format.

# %% [markdown]
# Note: Custom headers are given less precedence than more specific sources of information. For instance:
#
# - **Authorization headers set with headers= will be overridden** if credentials are specified in .netrc, which in turn will be overridden by the auth= parameter. Requests will search for the netrc file at ~/.netrc, ~/_netrc, or at the path specified by the NETRC environment variable.
#
# - **Authorization headers will be removed** if you get redirected off-host.
#
# - **Proxy-Authorization headers will be overridden** by proxy credentials provided in the URL.
#
# - **Content-Length headers will be overridden** when we can determine the length of the content.
#
# Furthermore, Requests does not change its behavior at all based on which custom headers are specified. The headers are simply passed on into the final request.
#
# Note: All header values must be a string, bytestring, or unicode. While permitted, it’s advised to avoid passing unicode header values.

# %% [markdown]
# ## 3.1 Authentication header
#
# There are many ways to do authentication in http request. Authentication header is one of them.
#
# ### 3.1.1 Api key

# %%
api_key = ""
headers = {'Authorization': f'Token {api_key}'}
response = requests.get('https://nautobot.demo.networktocode.com/api/dcim/devices/', headers=headers)

# %%
print(response)
# Out:
# <Response [403]>

# %% [markdown]
# ### 3.1.2 OIDC token

# %%
oidc_token = ""
headers = {'Authorization': f'Bearer {oidc_token}'}
base_url = 'https://webexapis.com'
# Get list of rooms
response = requests.get(f'{base_url}/v1/rooms', headers=headers)
print(response)
# Out:
# <Response [401]>

# %%
# Out:
# <Response [401]>

# %% [markdown]
# ### 3.1.3 Custom Token Header
# Some APIs require that the API key be provided in a custom header. For example, Cisco Meraki requires that all requests have an X-Cisco-Meraki-API-Key header with the API key as the value.

# %%
# The base URI for all requests
base_uri = "https://api.meraki.com/api/v0"

# Set the custom header to include the API key
headers = {'X-Cisco-Meraki-API-Key': api_key}

# Get a list of organizations
response = requests.get(f'{base_uri}/organizations', headers=headers)

print(response)
# Out:
# <Response [404]>

# %% [markdown]
# ### 3.1.4 Basic authentication
#
# For the basic login with login and password,

# %%
from requests.auth import HTTPBasicAuth

login = "admin"
password = "admin"
response = requests.get('https://api.github.com/user', auth=HTTPBasicAuth(login, password))
print(response)
# Out:
# ---------------------------------------------------------------------------
# CertificateError                          Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/pyhttpexample-8vE2bHV0-py3.8/lib/python3.8/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~/.cache/pypoetry/virtualenvs/pyhttpexample-8vE2bHV0-py3.8/lib/python3.8/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~/.cache/pypoetry/virtualenvs/pyhttpexample-8vE2bHV0-py3.8/lib/python3.8/site-packages/urllib3/connectionpool.py:1040, in HTTPSConnectionPool._validate_conn(self, conn)
#    1039 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1040     conn.connect()
#    1042 if not conn.is_verified:
#
# File ~/.cache/pypoetry/virtualenvs/pyhttpexample-8vE2bHV0-py3.8/lib/python3.8/site-packages/urllib3/connection.py:467, in HTTPSConnection.connect(self)
#     458         warnings.warn(
#     459             (
#     460                 "Certificate for {0} has no `subjectAltName`, falling back to check for a "
#    (...)
#     465             SubjectAltNameWarning,
#     466         )
# --> 467     _match_hostname(cert, self.assert_hostname or server_hostname)
#     469 self.is_verified = (
#     470     context.verify_mode == ssl.CERT_REQUIRED
#     471     or self.assert_fingerprint is not None
#     472 )
#
# File ~/.cache/pypoetry/virtualenvs/pyhttpexample-8vE2bHV0-py3.8/lib/python3.8/site-packages/urllib3/connection.py:540, in _match_hostname(cert, asserted_hostname)
#     539 try:
# --> 540     match_hostname(cert, asserted_hostname)
#     541 except CertificateError as e:
#
# File ~/.cache/pypoetry/virtualenvs/pyhttpexample-8vE2bHV0-py3.8/lib/python3.8/site-packages/urllib3/util/ssl_match_hostname.py:150, in match_hostname(cert, hostname)
#     149 if len(dnsnames) > 1:
# --> 150     raise CertificateError(
#     151         "hostname %r "
#     152         "doesn't match either of %s" % (hostname, ", ".join(map(repr, dnsnames)))
#     153     )
#     154 elif len(dnsnames) == 1:
#
# CertificateError: hostname 'api.github.com' doesn't match either of 'controller.access.network', 'central.access.network', 'wifiaccess.co'
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/pyhttpexample-8vE2bHV0-py3.8/lib/python3.8/site-packages/requests/adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     439 if not chunked:
# --> 440     resp = conn.urlopen(
#     441         method=request.method,
#     442         url=url,
#     443         body=request.body,
#     444         headers=request.headers,
#     445         redirect=False,
#     446         assert_same_host=False,
#     447         preload_content=False,
#     448         decode_content=False,
#     449         retries=self.max_retries,
#     450         timeout=timeout
#     451     )
#     453 # Send the request.
#     454 else:
#
# File ~/.cache/pypoetry/virtualenvs/pyhttpexample-8vE2bHV0-py3.8/lib/python3.8/site-packages/urllib3/connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     783     e = ProtocolError("Connection aborted.", e)
# --> 785 retries = retries.increment(
#     786     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787 )
#     788 retries.sleep()
#
# File ~/.cache/pypoetry/virtualenvs/pyhttpexample-8vE2bHV0-py3.8/lib/python3.8/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /user (Caused by SSLError(CertificateError("hostname 'api.github.com' doesn't match either of 'controller.access.network', 'central.access.network', 'wifiaccess.co'")))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# Input In [40], in <cell line: 5>()
#       3 login="admin"
#       4 password = "admin"
# ----> 5 response = requests.get('https://api.github.com/user', auth=HTTPBasicAuth(login, password))
#       6 print(response)
#
# File ~/.cache/pypoetry/virtualenvs/pyhttpexample-8vE2bHV0-py3.8/lib/python3.8/site-packages/requests/api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/pyhttpexample-8vE2bHV0-py3.8/lib/python3.8/site-packages/requests/api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/pyhttpexample-8vE2bHV0-py3.8/lib/python3.8/site-packages/requests/sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~/.cache/pypoetry/virtualenvs/pyhttpexample-8vE2bHV0-py3.8/lib/python3.8/site-packages/requests/sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File ~/.cache/pypoetry/virtualenvs/pyhttpexample-8vE2bHV0-py3.8/lib/python3.8/site-packages/requests/adapters.py:517, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     513         raise ProxyError(e, request=request)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
# --> 517         raise SSLError(e, request=request)
#     519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#
# SSLError: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /user (Caused by SSLError(CertificateError("hostname 'api.github.com' doesn't match either of 'controller.access.network', 'central.access.network', 'wifiaccess.co'")))

# %% [markdown]
# ## Some example

# %%
oidc_token = ""
headers = {'Authorization': f'Bearer {oidc_token}',
           "Content-Type": "application/json",
           "Accept": "application/json"}
url_base = "https://atlas.lab.sspcloud.fr/api/atlas/v2/search"
params = {"attrName": "qualifiedName",
          "attrValuePrefix": "user-pengfei@movies.Character",
          "limit": "10",
          "offset": "0",
          "typeName": "hive_table"}
response = requests.get(f"{url_base}/attribute", params=params, headers=headers)

# %%
response.text
# Out:
# '{"queryType":"BASIC","searchParameters":{"typeName":"hive_table","excludeDeletedEntities":false,"includeClassificationAttributes":false,"includeSubTypes":true,"includeSubClassifications":true,"limit":10,"offset":0,"entityFilters":{"attributeName":"qualifiedName","operator":"startsWith","attributeValue":"user-pengfei@movies.Character"}},"entities":[{"typeName":"hive_table","attributes":{"owner":"headless","createTime":1648021108,"qualifiedName":"user-pengfei@movies.Character","name":"Character","description":"favorite stock, test toto"},"guid":"26240d7d-395e-464e-ad58-1efda879d311","status":"ACTIVE","displayText":"Character","classificationNames":[],"meaningNames":[],"meanings":[],"isIncomplete":false,"labels":[]}],"approximateCount":10}'

# %%
post_payload={
  "typeName": "hive_table",
  "excludeDeletedEntities": True,
  "entityFilters": {
    "attributeName": "qualifiedName",
    "attributeValue": "user-pengfei@movies.Character",
    "operator": "startsWith"
  },
  "limit": 25,
  "offset": 0,
   "tagFilters": None,
  "attributes": [""]
}
# when your post payload is a json file, don't use data, use json as key argument
response = requests.post(f"{url_base}/basic", json=post_payload, headers=headers)

# %%
response.text
# Out:
# '{"queryType":"BASIC","searchParameters":{"typeName":"hive_table","excludeDeletedEntities":true,"includeClassificationAttributes":false,"includeSubTypes":true,"includeSubClassifications":true,"limit":25,"offset":0,"entityFilters":{"attributeName":"qualifiedName","operator":"startsWith","attributeValue":"user-pengfei@movies.Character"},"attributes":[""]},"entities":[{"typeName":"hive_table","attributes":{"owner":"headless","createTime":1648021108,"qualifiedName":"user-pengfei@movies.Character","name":"Character","description":"favorite stock, test toto"},"guid":"26240d7d-395e-464e-ad58-1efda879d311","status":"ACTIVE","displayText":"Character","classificationNames":[],"meaningNames":[],"meanings":[],"isIncomplete":false,"labels":[]}],"approximateCount":10}'

# %%
# data takes string as input type, not dict
response = requests.post(f"{url_base}/basic", data=post_payload, headers=headers)

# %% [markdown]
# There are many other point you may want to know about requests
#
# visit this page https://realpython.com/python-requests/#authentication

# %% [markdown]
# ## Common error response
#
# - 400: Bad Request is the status code to return when the form of the client request is not as the API expects.
# - 401: Unauthorized is the status code to return when the client provides no credentials or invalid credentials.
# - 403: Forbidden is the status code to return when a client has valid credentials but not enough privileges to perform an action on a resource.
# - 404: page not found
